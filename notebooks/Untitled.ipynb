# %% [markdown]
# import libraries

# %%
import numpy as np
import math
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# import file

# %%
xlsx_file_path = 'C:/Users/Lenovo/Desktop/ironhack/Week_5/Mid_bootcamp_project/data/raw/project_file.xlsx'

sheet_name = 'Data' 

data = pd.read_excel(xlsx_file_path, sheet_name=sheet_name)

# %% [markdown]
# visualize data

# %%
data.shape
# Out:
# (28261, 122)

# %%
data.head()
# Out:
#   UNECE/FAO TIMBER database, 1964-2021, as of March 2022.  Data point (yearD), status (yearS).  Status C=calculated (sum of subitems) - E1=technical estimate (based on similar data) - E2=analyst estimate (based on outside source) - E3=estimate based on official aggregate - R=repeated - N=national estimate - blank=official  \
# 0  Dollar values are at current prices and exchan...
# 1                                       Country Code
# 2                                                  8
# 3                                                  8
# 4                                                  8
#
#    Unnamed: 1                     Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0         NaN                            NaN           NaN        NaN
# 1  Country_ID                     Product_ID  Product Code       Flow
# 2     Albania  Roundwood (wood in the rough)             1    EXPORTS
# 3     Albania  Roundwood (wood in the rough)             1    EXPORTS
# 4     Albania  Roundwood (wood in the rough)             1    IMPORTS
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 112  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1       Unit      1964D      1964S      1965D      1965S  ...        2017D
# 2    1000 m3        NaN        NaN        NaN        NaN  ...        26.67
# 3   1000 US$        NaN        NaN        NaN        NaN  ...      1676.93
# 4    1000 m3        NaN        NaN        NaN        NaN  ...        30.47
#
#   Unnamed: 113 Unnamed: 114 Unnamed: 115 Unnamed: 116 Unnamed: 117  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1        2017S        2018D        2018S        2019D        2019S
# 2            C        15.35            C        14.02            C
# 3            C      1907.49            C      1804.94            C
# 4            C         23.8            C        18.46            C
#
#   Unnamed: 118 Unnamed: 119 Unnamed: 120 Unnamed: 121
# 0          NaN          NaN          NaN          NaN
# 1        2020D        2020S        2021D        2021S
# 2         11.8            C        14.26            C
# 3      1692.82            C      2214.79            C
# 4        39.04            C        23.37            C
#
# [5 rows x 122 columns]
